# %%
import pandas as pd 
import numpy as np
import pickle
from sklearn import set_config

set_config(transform_output="pandas")

# %%
model = pickle.load(open('titanic_pipe.pkl','rb'))

test_data = pd.DataFrame({
    'Sex': ['male'],
    'Age': [45.0],
    'SibSp': [0],
    'Parch': [0],
    'Fare': [26.55],
    'Embarked': ['S']
})

pred = model.predict(test_data)

pred



# predicted correctly that the passenger would not survive.
# orignal value array([[0, 'male', 19.0, 0, 0, 6.75, 'Q']], dtype=object)
# Out:
# array([0])
