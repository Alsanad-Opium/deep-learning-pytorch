# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression

# %%
# below are the keey steps to create the cleaner and more production ready pipeline and it doesnot contain the df loaded and the train teest split going on for it 
# only the steps to create the pipeline and train it and save it are mentioned here

# %%
num_features = ['Age','SibSp','Parch','Fare']
cat_features = ['Sex','Embarked']

# %%
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

# %%
cat_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor = ColumnTransformer([
    ('num', num_pipeline, num_features),
    ('cat', cat_pipeline, cat_features)
])

# %%
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression())
])

# %%
pipe.fit(X_train, y_train)

import pickle
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pipe.fit(X_train, y_train)
#       3 import pickle
#
# NameError: name 'X_train' is not defined

# %%
pickle.dump(pipe, open('titanic_pipe.pkl','wb'))
