# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score
from sklearn.ensemble import BaggingRegressor

# %%
from sklearn.datasets import make_regression

x,y = make_regression(n_samples=10000, n_features=10, noise=0.2)

x.shape,y.shape
# Out:
# ((10000, 10), (10000,))

# %%
x_train,x_test,y_train,y_test  = train_test_split(x,y,test_size=0.2, random_state=42)
x_train.shape,y_train.shape
# Out:
# ((8000, 10), (8000,))

# %%
tree = DecisionTreeRegressor(random_state=42)
knr = KNeighborsRegressor()
svr = SVR()

# %%
tree.fit(x_train,y_train)
knr.fit(x_train,y_train)
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
pred_tree = tree.predict(x_test)
pred_knr = knr.predict(x_test)
pred_svr = svr.predict(x_test)

# %%
print("R2_score of Tree ",r2_score(pred_tree,y_test))
print("R2_score of KNR ",r2_score(pred_knr,y_test))
print("R2_score of SVR ",r2_score(pred_svr,y_test))
# Out:
# R2_score of Tree  0.5806743040305917
# R2_score of KNR  0.8249083431987254
# R2_score of SVR  0.5340174853004518

# %%
bag = BaggingRegressor(estimator=DecisionTreeRegressor(random_state=42), n_estimators=500, max_samples=0.5,max_features=7, oob_score=True)

bag.fit(x_train,y_train)
bag_pred = bag.predict(x_test)
# Out:
# R2_score of Bagging is  0.5312994931540971

# %%
print("R2_score of Bagging is when model is decision tree  ", r2_score(bag_pred,y_test))

# %%
bag = BaggingRegressor(estimator=KNeighborsRegressor(), n_estimators=250, oob_score=True, n_jobs=-1)

bag.fit(x_train,y_train)
knr_bag_pred = bag.predict(x_test)

# %%
print("R2_score of Bagging when model is knr ", r2_score(knr_bag_pred,y_test))
# Out:
# R2_score of Bagging when model is knr  0.4125397657407549

# %%
bag = BaggingRegressor(estimator=SVR(), n_estimators=500, max_samples=0.5,max_features=7, oob_score=True, n_jobs = -1)

bag.fit(x_train,y_train)
svr_bag_pred = bag.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 bag = BaggingRegressor(estimator=SVR(), n_estimators=500, max_samples=0.5,max_features=7, oob_score=True, n_jobs = -1)
#       3 bag.fit(x_train,y_train)
# ----> 4 svr_bag_pred = bag.predict(x_test)
#
# File d:\Coding\deep-learning-pytorch\.venv\lib\site-packages\sklearn\ensemble\_bagging.py:1433, in BaggingRegressor.predict(self, X, **params)
#    1430 # Parallel loop
#    1431 n_jobs, _, starts = _partition_estimators(self.n_estimators, self.n_jobs)
# -> 1433 all_y_hat = Parallel(n_jobs=n_jobs, verbose=self.verbose)(
#    1434     delayed(_parallel_predict_regression)(
#    1435         self.estimators_[starts[i] : starts[i + 1]],
#    1436         self.estimators_features_[starts[i] : starts[i + 1]],
#    1437         X,
#    1438         params=routed_params.estimator.predict,
#    1439     )
# ...

# %%
print("R2_score of Bagging when model is knr ", r2_score(svr_bag_pred,y_test))
