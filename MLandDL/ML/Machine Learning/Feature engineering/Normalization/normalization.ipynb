# %%
import pandas as pd 
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('wine.csv')
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
df.sample(5)
# Out:
#     Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 21     1    12.93        3.80  2.65  18.6  102     2.41        2.41
# 83     2    13.05        3.86  2.32  22.5   85     1.65        1.59
# 71     2    13.86        1.51  2.67  25.0   86     2.95        2.86
# 6      1    14.39        1.87  2.45  14.6   96     2.50        2.52
# 84     2    11.84        0.89  2.58  18.0   94     2.20        2.21
#
#     Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 21                  0.25     1.98       4.50  1.03  3.52      770
# 83                  0.61     1.62       4.80  0.84  2.01      515
# 71                  0.21     1.87       3.38  1.36  3.16      410
# 6                   0.30     1.98       5.25  1.02  3.58     1290
# 84                  0.22     2.35       3.05  0.79  3.08      520

# %%
df = df.iloc[:,[0,1,2]]
df.sample(5)
# Out:
#      Wine  Alcohol  Malic.acid
# 94      2    11.62        1.99
# 9       1    13.86        1.35
# 21      1    12.93        3.80
# 147     3    12.87        4.61
# 114     2    12.08        1.39

# %%
df.shape
# Out:
# (178, 3)

# %%
x_train,x_test, y_train, y_test = train_test_split(df.iloc[:,[1,2]], df.iloc[:,0],test_size=0.2, random_state=42)

# %%
x_train.head()
# Out:
#      Alcohol  Malic.acid
# 158    14.34        1.68
# 137    12.53        5.51
# 98     12.37        1.07
# 159    13.48        1.67
# 38     13.07        1.50

# %%
x_test.head()
# Out:
#      Alcohol  Malic.acid
# 19     13.64        3.10
# 45     14.21        4.04
# 140    12.93        2.81
# 30     13.73        1.50
# 67     12.37        1.17

# %%
x_train.shape
# Out:
# (142, 2)

# %%
x_test.shape
# Out:
# (36, 2)

# %%
sns.scatterplot(x = x_train["Alcohol"],y= x_train['Malic.acid'],hue=y_train)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic.acid'>

# %%
scaler = MinMaxScaler()

scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[0.87105263, 0.16089613],
#        [0.39473684, 0.94093686],
#        [0.35263158, 0.03665988],
#        [0.64473684, 0.15885947],
#        [0.53684211, 0.12423625],
#        [0.31315789, 0.0814664 ],
#        [0.43157895, 0.01832994],
#        [0.60789474, 0.0101833 ],
#        [0.68157895, 0.82688391],
#        [0.56052632, 0.299389  ],
#        [0.27631579, 0.24236253],
#        [0.36578947, 0.7209776 ],
#        [0.40789474, 0.0814664 ],
#        [0.73684211, 0.15478615],
#        [0.52631579, 0.00203666],
#        [0.83947368, 0.16496945],
#        [0.62105263, 0.17922607],
#        [0.57894737, 0.49083503],
#        [0.64736842, 0.54989817],
#        [0.38947368, 0.17107943],
#        [0.34210526, 0.0203666 ],
#        [0.59210526, 0.15274949],
#        [0.33157895, 0.39511202],
#        [0.70526316, 0.19755601],
#        [0.75      , 0.84521385],
#        [0.33157895, 0.10590631],
#        [0.31052632, 0.0610998 ],
#        [0.47105263, 0.50509165],
# ...

# %%
x_train_scaled = pd.DataFrame(x_train_scaled,columns = x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns=x_test.columns)

# %%
x_train_scaled.sample(5)
# Out:
#       Alcohol  Malic.acid
# 123  0.671053    0.344196
# 46   0.747368    0.205703
# 5    0.313158    0.081466
# 137  0.744737    0.126273
# 36   0.165789    0.201629

# %%
x_test_scaled.sample(5)
# Out:
#      Alcohol  Malic.acid
# 7   0.623684    0.615071
# 30  0.786842    0.160896
# 12  0.626316    0.600815
# 2   0.500000    0.391039
# 31  0.352632    0.150713

# %%
sns.scatterplot(x= x_train_scaled['Alcohol'],y= x_train_scaled['Malic.acid'],hue = y_train)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic.acid'>
